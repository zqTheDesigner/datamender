# %%
from datamender.datasets import timeseries_products

# %%
t_data = timeseries_products.load_data()

# %%
t_data.isnull().sum()
# Out:
# t              0
# ProductP1      0
# ProductP2      0
# ProductP3      0
# ProductP4      0
# ProductP5      0
# price          0
# temperature    0
# dtype: int64

# %%
t_data
# Out:
#       t  ProductP1  ProductP2  ProductP3  ProductP4  ProductP5  price
# 0     1        197         66        266        113          2      1  \
# 1     2        153         44        264         74          1      2
# 2     3        128         55        317        116          0      1
# 3     4        133         57        390         70          0      2
# 4     5        120         47        440        141          1      1
# ..  ...        ...        ...        ...        ...        ...    ...
# 95   96        174        226        975         94          0      1
# 96   97        158        201       1141         91          0      2
# 97   98        145        217        881         46          4      1
# 98   99        161        249        741         70          0      1
# 99  100        160        331        854         75          0      1
#
#     temperature
# 0            18
# 1            21
# 2            19
# 3            17
# 4            18
# ..          ...
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(t_data['ProductP1'])
plt.plot(t_data['ProductP2'])
plt.plot(t_data['ProductP3'])
plt.plot(t_data['ProductP4'])
plt.plot(t_data['ProductP5'])
plt.plot(t_data['temperature'] * 100)
